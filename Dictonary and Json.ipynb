# %%
'''Dictonary and Json '''
#-----------------------------------------------------------------------------
#Deleration-----
'''
<Dictonary_name> = { Key1:Value1,key2:value2,-------keyn:valuen}

'''
'''
properties:
->has any number of key and value.
->key and value can be any datatype.
->keys and values are iterable.
->add,delete,change*,key
->check key of ready exist or not.
->
'''
# type of deceleration
a=(1,"hari",200)
b={
    "id":1,
    "name":"Hari",
    "bonus":2000,
    "has_veichle":True
}
print(a)
print(type(a))
print("--------------------------------------------------------------")

print(b)
print(type(b))
print("--------------------------------------------------------------")

print(b["bonus"])# need "--"
print("--------------------------------------------------------------")

b['salary']=50000 #insert new value
print(b)
print("--------------------------------------------------------------")

b['name']="Ashesh"# update value
print(b)
print(b['name'])
print("--------------------------------------------------------------")

del b["bonus"]#delete value------------------
print(b)
print("--------------------------------------------------------------")

print(b.keys())#gives the key value of each element
print("--------------------------------------------------------------")

print(b.values())# gives the assign value of each element
print("--------------------------------------------------------------")

for key in b.keys():
    print("The value of "+key+"="+str(b[key]))
print("--------------------------------------------------------------")
#--------------------------------------------------------------------

for key,value in b.items():
    print("The value of "+key+"="+str(value))
print("--------------------------------------------------------------")

#print(["The value of "+str(key)+"="+str(value)+"for key,value in "+b.items()])# error---------********

print("--------------------------------------------------------------")
b=[key for key in b.keys()]
print('name' in b)#checks key in dict or not
print("--------------------------------------------------------------")
print('names' in b)
print("--------------------------------------------------------------")

#print(b['name'])

print("--------------------------------------------------------------")
if 'names' in a:
    print(a['names'])
else:
    print("No key found")
# Out:
# (1, 'hari', 200)
# <class 'tuple'>
# --------------------------------------------------------------
# {'id': 1, 'name': 'Hari', 'bonus': 2000, 'has_veichle': True}
# <class 'dict'>
# --------------------------------------------------------------
# 2000
# --------------------------------------------------------------
# {'id': 1, 'name': 'Hari', 'bonus': 2000, 'has_veichle': True, 'salary': 50000}
# --------------------------------------------------------------
# {'id': 1, 'name': 'Ashesh', 'bonus': 2000, 'has_veichle': True, 'salary': 50000}
# Ashesh
# --------------------------------------------------------------
# {'id': 1, 'name': 'Ashesh', 'has_veichle': True, 'salary': 50000}
# --------------------------------------------------------------
# dict_keys(['id', 'name', 'has_veichle', 'salary'])
# --------------------------------------------------------------
# dict_values([1, 'Ashesh', True, 50000])
# --------------------------------------------------------------
# ...

# %%
print("------------------------------------------------------------------")
print("-----------------------Json---------------------------------------")
print("------------------------------------------------------------------")


'''
=>Two types of Json.
     ->Json object---->Dictionary
     ->Json array----->list of dictonary
=>key is always string ****

'''
